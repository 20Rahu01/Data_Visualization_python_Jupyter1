# %%
import pandas as pd

# %%
import xlrd as x

# %%
df=pd.read_csv('emp.csv')

# %%
df
# Out:
#      id             name gender  age  salary
# 0  1001       Ganesh Rao      M   25      20
# 1  1002          Lakshmi      F   22      20
# 2  1003      Vinod Kumar      M   30      22
# 3  1004           Neelam      F   33      30
# 4  1005          Reethu       F   21      19
# 5  1006    Gaurav Pandey      M   40      25
# 6  1007         Kulkarni      M   30      24
# 7  1008  Vishal Muhammad      M   29      19
# 8  1009      Meena Singh      F   25      21
# 9  1010   Ankhit Chandra      M   40      26

# %%
# Viewing data from df

# %%
# for that use loc() --> called as locate function

# %%
# Another is there called iloc() --> called as index based locate function

# %%
df1 = df.loc[:,['name','gender']]

# %%
df1
# Out:
#               name gender
# 0       Ganesh Rao      M
# 1          Lakshmi      F
# 2      Vinod Kumar      M
# 3           Neelam      F
# 4          Reethu       F
# 5    Gaurav Pandey      M
# 6         Kulkarni      M
# 7  Vishal Muhammad      M
# 8      Meena Singh      F
# 9   Ankhit Chandra      M

# %%
df1 = df.iloc[:,[1,3]]

# %%
df1
# Out:
#               name  age
# 0       Ganesh Rao   25
# 1          Lakshmi   22
# 2      Vinod Kumar   30
# 3           Neelam   33
# 4          Reethu    21
# 5    Gaurav Pandey   40
# 6         Kulkarni   30
# 7  Vishal Muhammad   29
# 8      Meena Singh   25
# 9   Ankhit Chandra   40

# %%
df1 = df.iloc[0:3,[1,3]]

# %%
df1
# Out:
#           name  age
# 0   Ganesh Rao   25
# 1      Lakshmi   22
# 2  Vinod Kumar   30

# %%
df
# Out:
#      id             name gender  age  salary
# 0  1001       Ganesh Rao      M   25      20
# 1  1002          Lakshmi      F   22      20
# 2  1003      Vinod Kumar      M   30      22
# 3  1004           Neelam      F   33      30
# 4  1005          Reethu       F   21      19
# 5  1006    Gaurav Pandey      M   40      25
# 6  1007         Kulkarni      M   30      24
# 7  1008  Vishal Muhammad      M   29      19
# 8  1009      Meena Singh      F   25      21
# 9  1010   Ankhit Chandra      M   40      26

# %%
df.shape
# Out:
# (10, 5)

# %%
r,c = df.shape

# %%
c
# Out:
# 5

# %%
r
# Out:
# 10

# %%
print(r)
# Out:
# 10

# %%
df.head()  # getting first 5 output
# Out:
#      id         name gender  age  salary
# 0  1001   Ganesh Rao      M   25      20
# 1  1002      Lakshmi      F   22      20
# 2  1003  Vinod Kumar      M   30      22
# 3  1004       Neelam      F   33      30
# 4  1005      Reethu       F   21      19

# %%
df.tail()  # getting last 5 output
# Out:
#      id             name gender  age  salary
# 5  1006    Gaurav Pandey      M   40      25
# 6  1007         Kulkarni      M   30      24
# 7  1008  Vishal Muhammad      M   29      19
# 8  1009      Meena Singh      F   25      21
# 9  1010   Ankhit Chandra      M   40      26

# %%
df.head(2)
# Out:
#      id        name gender  age  salary
# 0  1001  Ganesh Rao      M   25      20
# 1  1002     Lakshmi      F   22      20

# %%
df[2:5]
# Out:
#      id         name gender  age  salary
# 2  1003  Vinod Kumar      M   30      22
# 3  1004       Neelam      F   33      30
# 4  1005      Reethu       F   21      19

# %%
df[0::2]  # printing alternate output
# Out:
#      id         name gender  age  salary
# 0  1001   Ganesh Rao      M   25      20
# 2  1003  Vinod Kumar      M   30      22
# 4  1005      Reethu       F   21      19
# 6  1007     Kulkarni      M   30      24
# 8  1009  Meena Singh      F   25      21

# %%
 df.columns
# Out:
# Index(['id', 'name', 'gender', 'age', 'salary'], dtype='object')

# %%
df.name
# Out:
# 0         Ganesh Rao
# 1            Lakshmi
# 2        Vinod Kumar
# 3             Neelam
# 4            Reethu
# 5      Gaurav Pandey
# 6           Kulkarni
# 7    Vishal Muhammad
# 8        Meena Singh
# 9     Ankhit Chandra
# Name: name, dtype: object

# %%
df[['name','age']]  # for showing multiple columns
# Out:
#               name  age
# 0       Ganesh Rao   25
# 1          Lakshmi   22
# 2      Vinod Kumar   30
# 3           Neelam   33
# 4          Reethu    21
# 5    Gaurav Pandey   40
# 6         Kulkarni   30
# 7  Vishal Muhammad   29
# 8      Meena Singh   25
# 9   Ankhit Chandra   40

# %%
df.salary
# Out:
# 0    20
# 1    20
# 2    22
# 3    30
# 4    19
# 5    25
# 6    24
# 7    19
# 8    21
# 9    26
# Name: salary, dtype: int64

# %%
df.salary.max()
# Out:
# 30

# %%
df.describe()
# Out:
#                id        age     salary
# count    10.00000  10.000000  10.000000
# mean   1005.50000  29.500000  22.600000
# std       3.02765   6.687468   3.596294
# min    1001.00000  21.000000  19.000000
# 25%    1003.25000  25.000000  20.000000
# 50%    1005.50000  29.500000  21.500000
# 75%    1007.75000  32.250000  24.750000
# max    1010.00000  40.000000  30.000000

# %%
df.salary>12
# Out:
# 0    True
# 1    True
# 2    True
# 3    True
# 4    True
# 5    True
# 6    True
# 7    True
# 8    True
# 9    True
# Name: salary, dtype: bool

# %%
df3
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[32], line 1
# ----> 1 df3
#
# NameError: name 'df3' is not defined

# %%
df[df.salary>12]
# Out:
#      id             name gender  age  salary
# 0  1001       Ganesh Rao      M   25      20
# 1  1002          Lakshmi      F   22      20
# 2  1003      Vinod Kumar      M   30      22
# 3  1004           Neelam      F   33      30
# 4  1005          Reethu       F   21      19
# 5  1006    Gaurav Pandey      M   40      25
# 6  1007         Kulkarni      M   30      24
# 7  1008  Vishal Muhammad      M   29      19
# 8  1009      Meena Singh      F   25      21
# 9  1010   Ankhit Chandra      M   40      26

# %%
df[df.salary>21]
# Out:
#      id            name gender  age  salary
# 2  1003     Vinod Kumar      M   30      22
# 3  1004          Neelam      F   33      30
# 5  1006   Gaurav Pandey      M   40      25
# 6  1007        Kulkarni      M   30      24
# 9  1010  Ankhit Chandra      M   40      26

# %%
df[df.salary == df.salary.max()] # comparing with
# Out:
#      id    name gender  age  salary
# 3  1004  Neelam      F   33      30

# %%
x = df.sort_values('salary')

# %%
x
# Out:
#      id             name gender  age  salary
# 4  1005          Reethu       F   21      19
# 7  1008  Vishal Muhammad      M   29      19
# 0  1001       Ganesh Rao      M   25      20
# 1  1002          Lakshmi      F   22      20
# 8  1009      Meena Singh      F   25      21
# 2  1003      Vinod Kumar      M   30      22
# 6  1007         Kulkarni      M   30      24
# 5  1006    Gaurav Pandey      M   40      25
# 9  1010   Ankhit Chandra      M   40      26
# 3  1004           Neelam      F   33      30

# %%
df2 = pd.read_csv('read.csv')

# %%
df2
# Out:
#       id             name gender  age  salary
# 0   1001       Ganesh Rao      M   25    20.0
# 1   1002          Lakshmi      F   22    20.0
# 2   1003      Vinod Kumar      M   30    22.0
# 3   1018              NaN      M   42  1000.0
# 4   1004           Neelam      F   33    30.0
# 5   1005          Reethu       F   21    19.0
# 6   1006    Gaurav Pandey      M   40    25.0
# 7   1007         Kulkarni      M   30    24.0
# 8   1008  Vishal Muhammad      M   29    19.0
# 9   1009      Meena Singh      F   25    21.0
# 10  1010   Ankhit Chandra      M   40    26.0
# 11  1012            Rahul      M   42     NaN

# %%
# here NaN is the missing value. This is not null value. Called "default marker for missing value"

# %%
# locating NaN [here df2 using as dataset]
df2.fillna(0)
# Out:
#       id             name gender  age  salary
# 0   1001       Ganesh Rao      M   25    20.0
# 1   1002          Lakshmi      F   22    20.0
# 2   1003      Vinod Kumar      M   30    22.0
# 3   1018                0      M   42  1000.0
# 4   1004           Neelam      F   33    30.0
# 5   1005          Reethu       F   21    19.0
# 6   1006    Gaurav Pandey      M   40    25.0
# 7   1007         Kulkarni      M   30    24.0
# 8   1008  Vishal Muhammad      M   29    19.0
# 9   1009      Meena Singh      F   25    21.0
# 10  1010   Ankhit Chandra      M   40    26.0
# 11  1012            Rahul      M   42     0.0

# %%
df2.fillna({'name':'NAME IS MISSING','salary': 0.0})
# Out:
#       id             name gender  age  salary
# 0   1001       Ganesh Rao      M   25    20.0
# 1   1002          Lakshmi      F   22    20.0
# 2   1003      Vinod Kumar      M   30    22.0
# 3   1018  NAME IS MISSING      M   42  1000.0
# 4   1004           Neelam      F   33    30.0
# 5   1005          Reethu       F   21    19.0
# 6   1006    Gaurav Pandey      M   40    25.0
# 7   1007         Kulkarni      M   30    24.0
# 8   1008  Vishal Muhammad      M   29    19.0
# 9   1009      Meena Singh      F   25    21.0
# 10  1010   Ankhit Chandra      M   40    26.0
# 11  1012            Rahul      M   42     0.0

# %%
df20 = pd.DataFrame({'name':['rd','vk','sg'],'gender':['M','M','M'],'age':[30,24,31]})

# %%
df20
# Out:
#   name gender  age
# 0   rd      M   30
# 1   vk      M   24
# 2   sg      M   31

# %%
df21 = pd.DataFrame({'name':['rd','vk','sg'],'position':['all','bat','ball'],'sal':[50000,80000,60000]})

# %%
df21
# Out:
#   name position    sal
# 0   rd      all  50000
# 1   vk      bat  80000
# 2   sg     ball  60000

# %%
pd.merge(df20,df21,on='name',how='inner')
# Out:
#   name gender  age position    sal
# 0   rd      M   30      all  50000
# 1   vk      M   24      bat  80000
# 2   sg      M   31     ball  60000

# %%
pd.merge(df20,df21,on='name',how='left')
# Out:
#   name gender  age position    sal
# 0   rd      M   30      all  50000
# 1   vk      M   24      bat  80000
# 2   sg      M   31     ball  60000

# %%
pd.merge(df20,df21,on='name',how='right')
# Out:
#   name gender  age position    sal
# 0   rd      M   30      all  50000
# 1   vk      M   24      bat  80000
# 2   sg      M   31     ball  60000

# %%
pd.merge(df20,df21,on='name',how='outer')
# Out:
#   name gender  age position    sal
# 0   rd      M   30      all  50000
# 1   vk      M   24      bat  80000
# 2   sg      M   31     ball  60000

# %%
# data visualization
pip install matplotlib
# bar graph
# Out:
#   Cell In[85], line 2
#     pip install matplotlib
#         ^
# SyntaxError: invalid syntax

# %%
import matplotlib.pyplot as plt

# %%
df2
# Out:
#       id             name gender  age  salary
# 0   1001       Ganesh Rao      M   25    20.0
# 1   1002          Lakshmi      F   22    20.0
# 2   1003      Vinod Kumar      M   30    22.0
# 3   1018              NaN      M   42  1000.0
# 4   1004           Neelam      F   33    30.0
# 5   1005          Reethu       F   21    19.0
# 6   1006    Gaurav Pandey      M   40    25.0
# 7   1007         Kulkarni      M   30    24.0
# 8   1008  Vishal Muhammad      M   29    19.0
# 9   1009      Meena Singh      F   25    21.0
# 10  1010   Ankhit Chandra      M   40    26.0
# 11  1012            Rahul      M   42     NaN

# %%
x = df2['name']

# %%
y = df2['salary']

# %%
x
# Out:
# 0          Ganesh Rao
# 1             Lakshmi
# 2         Vinod Kumar
# 3                 NaN
# 4              Neelam
# 5             Reethu
# 6       Gaurav Pandey
# 7            Kulkarni
# 8     Vishal Muhammad
# 9         Meena Singh
# 10     Ankhit Chandra
# 11              Rahul
# Name: name, dtype: object

# %%
y
# Out:
# 0       20.0
# 1       20.0
# 2       22.0
# 3     1000.0
# 4       30.0
# 5       19.0
# 6       25.0
# 7       24.0
# 8       19.0
# 9       21.0
# 10      26.0
# 11       NaN
# Name: salary, dtype: float64

# %%
plt.bar(x,y,label='employee data', color='red'
       )
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[92], line 1
# ----> 1 plt.bar(x,y,label='employee data', color='red'
#       2        )
#
# File C:\Python3.9.12\lib\site-packages\matplotlib\pyplot.py:2367, in bar(x, height, width, bottom, align, data, **kwargs)
#    2363 @_copy_docstring_and_deprecators(Axes.bar)
#    2364 def bar(
#    2365         x, height, width=0.8, bottom=None, *, align='center',
#    2366         data=None, **kwargs):
# -> 2367     return gca().bar(
#    2368         x, height, width=width, bottom=bottom, align=align,
#    2369         **({"data": data} if data is not None else {}), **kwargs)
#
# File C:\Python3.9.12\lib\site-packages\matplotlib\__init__.py:1423, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1420 @functools.wraps(func)
#    1421 def inner(ax, *args, data=None, **kwargs):
#    1422     if data is None:
# -> 1423         return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1425     bound = new_sig.bind(ax, *args, **kwargs)
#    1426     auto_label = (bound.arguments.get(label_namer)
#    1427                   or bound.kwargs.get(label_namer))
#
# File C:\Python3.9.12\lib\site-packages\matplotlib\axes\_axes.py:2366, in Axes.bar(self, x, height, width, bottom, align, **kwargs)
#    2363         x = 0
#    2365 if orientation == 'vertical':
# -> 2366     self._process_unit_info(
#    2367         [("x", x), ("y", height)], kwargs, convert=False)
#    2368     if log:
#    2369         self.set_yscale('log', nonpositive='clip')
#
# File C:\Python3.9.12\lib\site-packages\matplotlib\axes\_base.py:2585, in _AxesBase._process_unit_info(self, datasets, kwargs, convert)
#    2583     # Update from data if axis is already set but no unit is set yet.
#    2584     if axis is not None and data is not None and not axis.have_units():
# -> 2585         axis.update_units(data)
#    2586 for axis_name, axis in axis_map.items():
#    2587     # Return if no axis is set.
#    2588     if axis is None:
#
# File C:\Python3.9.12\lib\site-packages\matplotlib\axis.py:1608, in Axis.update_units(self, data)
#    1606 neednew = self.converter != converter
#    1607 self.converter = converter
# -> 1608 default = self.converter.default_units(data, self)
#    1609 if default is not None and self.units is None:
#    1610     self.set_units(default)
#
# File C:\Python3.9.12\lib\site-packages\matplotlib\category.py:116, in StrCategoryConverter.default_units(data, axis)
#     114 # the conversion call stack is default_units -> axis_info -> convert
#     115 if axis.units is None:
# --> 116     axis.set_units(UnitData(data))
#     117 else:
#     118     axis.units.update(data)
#
# File C:\Python3.9.12\lib\site-packages\matplotlib\category.py:192, in UnitData.__init__(self, data)
#     190 self._counter = itertools.count()
#     191 if data is not None:
# --> 192     self.update(data)
#
# File C:\Python3.9.12\lib\site-packages\matplotlib\category.py:227, in UnitData.update(self, data)
#     224 convertible = True
#     225 for val in OrderedDict.fromkeys(data):
#     226     # OrderedDict just iterates over unique values in data.
# --> 227     _api.check_isinstance((str, bytes), value=val)
#     228     if convertible:
#     229         # this will only be called so long as convertible is True.
#     230         convertible = self._str_is_convertible(val)
#
# File C:\Python3.9.12\lib\site-packages\matplotlib\_api\__init__.py:93, in check_isinstance(_types, **kwargs)
#      91     names.remove("None")
#      92     names.append("None")
# ---> 93 raise TypeError(
#      94     "{!r} must be an instance of {}, not a {}".format(
#      95         k,
#      96         ", ".join(names[:-1]) + " or " + names[-1]
#      97         if len(names) > 1 else names[0],
#      98         type_name(type(v))))
#
# TypeError: 'value' must be an instance of str or bytes, not a float

# %%
plt.xlabel('emp name')
plt.ylabel('emp salary')
# Out:
# Text(0, 0.5, 'emp salary')

# %%
plt.xlabel('emp name')
plt.ylabel('emp salary')
plt.title('my company')
plt.legend()
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
import matplotlib.pyplot as plt
import pandas as pd
a = pd.read_csv('ss.csv')
d=pd.DataFrame(a)
x = d['name']
y = d['age']
plt.bar(x,y,label='employee data', color='red')
plt.xlabel('emp name')
plt.ylabel('emp age')
plt.title('my company')
plt.legend()
plt.show()
